# %% [markdown]
# https://ved933409.medium.com/major-reasons-why-machine-learning-fails-in-stock-prediction-part-01-479834eb891d
#
# Advance in finance machine learning by Marcos López de Prado
# ![image.png](attachment:fa3782b3-ffe9-434e-8932-8559100c6bff.png)
#
# ![image.png](attachment:a71291ef-d733-4eb6-b473-861552ec526a.png)

# %% [markdown]
# ![image.png](attachment:ac2adf82-6ec1-40fa-a9f7-79dc5875a8b6.png)

# %% [markdown]
# ![image.png](attachment:b6121317-7e72-4780-8ce6-7dec3dace755.png)

# %% [markdown]
# ＃＃＃Tick bar: all the variable like timestamp, volume, open price, close e.g is extracted after a finite no of transactions take place. for example we sample all variable after 1000 transactions. Mandelbrot and Taylor [1967] were among the first to realize that sampling as a function of the number of transactions exhibited desirable statistical properties: “Price changes over a fixed number of transactions may have a Gaussian distribution.

# %% [markdown]
# ## “ one important thing to take care of while constructing any bar is of outliers because many exchange for some period of time while opening of market and closing of market accumulates bid and ask offer in orderbook without matching them. so you can see a outlier behavior for some time while opening and closing of market”

# %% [markdown]
# ![image.png](attachment:f6722b23-635e-4c76-b89b-6eec4e8d166e.png)
# Time bar plot of a stock

# %% [markdown]
# 　![image.png](attachment:a246f5ea-8d14-40f8-9196-e9ceeff2c004.png)
#  Tick bar of same stock (we can see the plot is more smooth compare to time bar)

# %% [markdown]
# https://www.blackarbs.com/blog/the-secret-to-shorting-stocks
# ## blackarbs LLC Strategy

# %% [markdown]
# ![image.png](attachment:8bc97f3b-7e6c-4bf8-9ac3-4945ac74419d.png)

# %% [markdown]
# ## BENCHMARK STRATEGY:
# This is a market neutral long-short strategy using a custom version of Quantconnect’s S&P 500 universe filter
# ## REGIME FILTERED (RF) STRATEGY:
# is strategy adds the regime classification method to the aforementioned benchmark strategy.
#
# It requires the long stocks to be in a bull regime, and the short stocks to be in a bear regime as determined by the regime classifier..

# %% [markdown]
# ![image.png](attachment:c6d52254-7a16-4308-b972-eec63cc7705b.png)

# %% [markdown]
# ![image.png](attachment:4228048b-dc54-4997-8abb-5ce098177316.png)
